# %%
# Vérifier si LaTeX est installé
# !which latex

import subprocess
result = subprocess.run(['kpsewhich', 'standalone.cls'], capture_output=True, text=True)
print("standalone.cls:", result.stdout or "NON TROUVÉ")
# Out:
# /usr/bin/latex
# standalone.cls: NON TROUVÉ

# %%
import manim as mn
from manim import *

config.media_width = "75%"
config.verbosity = "WARNING"

print(mn.__version__)
# Out:
# 0.20.1

# %%
# %%manim -ql Intro
#
# class Intro(Scene):
#     def construct(self):
#         plus_symb = MathTex(r"+")
#
#         self.play(Write(plus_symb))
#         self.wait()
# Out:
# Manim Community v0.20.1
# [04/20/26 16:32:10] ERROR    LaTeX compilation error: LaTeX Error: File `standalone.cls'    ]8;id=15838840;file:///srv/conda/envs/notebook/lib/python3.11/site-packages/manim/utils/tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=15838841;file:///srv/conda/envs/notebook/lib/python3.11/site-packages/manim/utils/tex_file_writing.py#313\313]8;;\
#                              not found.
#                     ERROR    Context of error:                                              ]8;id=15838847;file:///srv/conda/envs/notebook/lib/python3.11/site-packages/manim/utils/tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=15838848;file:///srv/conda/envs/notebook/lib/python3.11/site-packages/manim/utils/tex_file_writing.py#347\347]8;;\
#                              -> \documentclass[preview]{standalone}
#                              \usepackage[english]{babel}
#                              \usepackage{amsmath}
#                              \usepackage{amssymb}
#                     ERROR    LaTeX compilation error: Emergency stop.                       ]8;id=15838853;file:///srv/conda/envs/notebook/lib/python3.11/site-packages/manim/utils/tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=15838854;file:///srv/conda/envs/notebook/lib/python3.11/site-packages/manim/utils/tex_file_writing.py#313\313]8;;\
#                     ERROR    Context of error:                                              ]8;id=15838859;file:///srv/conda/envs/notebook/lib/python3.11/site-packages/manim/utils/tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=15838860;file:///srv/conda/envs/notebook/lib/python3.11/site-packages/manim/utils/tex_file_writing.py#347\347]8;;\
#                              -> \documentclass[preview]{standalone}
#                              \usepackage[english]{babel}
#                              \usepackage{amsmath}
#                              \usepackage{amssymb}
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 get_ipython().run_cell_magic('manim', '-ql Intro', '\nclass Intro(Scene):\n    def construct(self):\n        plus_symb = MathTex(r"+")\n\n        self.play(Write(plus_symb))\n        self.wait()\n')
#
# File /srv/conda/envs/notebook/lib/python3.11/site-packages/IPython/core/interactiveshell.py:2565, in InteractiveShell.run_cell_magic(self, magic_name, line, cell)
#    2563 with self.builtin_trap:
#    2564     args = (magic_arg_s, cell)
# -> 2565     result = fn(*args, **kwargs)
#    2567 # The code below prevents the output from being displayed
#    2568 # when using magics with decorator @output_can_be_silenced
#    2569 # when the last Python token in the expression is a ';'.
#    2570 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File /srv/conda/envs/notebook/lib/python3.11/site-packages/manim/utils/ipython_magic.py:143, in ManimMagic.manim(self, line, cell, local_ns)
#     141     SceneClass = local_ns[config["scene_names"][0]]
#     142     scene = SceneClass(renderer=renderer)
# --> 143     scene.render()
#     144 finally:
#     145     # Shader cache becomes invalid as the context is destroyed
#     146     shader_program_cache.clear()
#
# File /srv/conda/envs/notebook/lib/python3.11/site-packages/manim/scene/scene.py:259, in Scene.render(self, preview)
#     257 self.setup()
#     258 try:
# --> 259     self.construct()
#     260 except EndSceneEarlyException:
#     261     pass
#
# File <string>:4, in construct(self)
#
# File /srv/conda/envs/notebook/lib/python3.11/site-packages/manim/mobject/text/tex_mobject.py:329, in MathTex.__init__(self, arg_separator, substrings_to_isolate, tex_to_color_map, tex_environment, *tex_strings, **kwargs)
#     316     if self.brace_notation_split_occurred:
#     317         logger.error(
#     318             dedent(
#     319                 """\
#    (...)    327             ),
#     328         )
# --> 329     raise compilation_error
#     330 self.set_color_by_tex_to_color_map(self.tex_to_color_map)
#     332 if self.organize_left_to_right:
#
# File /srv/conda/envs/notebook/lib/python3.11/site-packages/manim/mobject/text/tex_mobject.py:306, in MathTex.__init__(self, arg_separator, substrings_to_isolate, tex_to_color_map, tex_environment, *tex_strings, **kwargs)
#     302 try:
#     303     joined_string = self._join_tex_strings_with_unique_deliminters(
#     304         self.tex_strings, self.substrings_to_isolate
#     305     )
# --> 306     super().__init__(
#     307         joined_string,
#     308         tex_environment=self.tex_environment,
#     309         tex_template=self.tex_template,
#     310         **kwargs,
#     311     )
#     312     # Save the original tex_string
#     313     self.tex_string = self.arg_separator.join(self.tex_strings)
#
# File /srv/conda/envs/notebook/lib/python3.11/site-packages/manim/mobject/text/tex_mobject.py:81, in SingleStringMathTex.__init__(self, tex_string, stroke_width, should_center, height, organize_left_to_right, tex_environment, tex_template, font_size, color, **kwargs)
#      78 self.tex_template: TexTemplate = tex_template
#      80 self.tex_string = tex_string
# ---> 81 file_name = tex_to_svg_file(
#      82     self._get_modified_expression(tex_string),
#      83     environment=self.tex_environment,
#      84     tex_template=self.tex_template,
#      85 )
#      86 super().__init__(
#      87     file_name=file_name,
#      88     should_center=should_center,
#    (...)     96     **kwargs,
#      97 )
#      98 self.init_colors()
#
# File /srv/conda/envs/notebook/lib/python3.11/site-packages/manim/utils/tex_file_writing.py:65, in tex_to_svg_file(expression, environment, tex_template)
#      62 if svg_file.exists():
#      63     return svg_file
# ---> 65 dvi_file = compile_tex(
#      66     tex_file,
#      67     tex_template.tex_compiler,
#      68     tex_template.output_format,
#      69 )
#      70 svg_file = convert_to_svg(dvi_file, tex_template.output_format)
#      71 if not config["no_latex_cleanup"]:
#
# File /srv/conda/envs/notebook/lib/python3.11/site-packages/manim/utils/tex_file_writing.py:211, in compile_tex(tex_file, tex_compiler, output_format)
#     209         log_file = tex_file.with_suffix(".log")
#     210         print_all_tex_errors(log_file, tex_compiler, tex_file)
# --> 211         raise ValueError(
#     212             f"{tex_compiler} error converting to"
#     213             f" {output_format[1:]}. See log output above or"
#     214             f" the log file: {log_file}",
#     215         )
#     216 return result
#
# ValueError: latex error converting to dvi. See log output above or the log file: media/Tex/713151ed93a8b1f5.log

# %%
# %%manim -qh DotsCreation
#
# class DotsCreation(Scene):
#     def construct(self):
#         red_dot = Dot(color=RED)
#         blue_dot = Dot(color=BLUE)
#         white_dot = Dot(color=WHITE)
#
#         red_grid = VGroup(*[red_dot.copy() for _ in range(10)])
#         blue_grid = VGroup(*[blue_dot.copy() for _ in range(7)])
#
#         red_grid.arrange_in_grid(rows=1, buff=0.2)
#         blue_grid.arrange_in_grid(rows=1, buff=0.2)
#
#         self.play(DrawBorderThenFill(red_grid))
#         self.play(red_grid.animate.to_edge(LEFT))
#         self.wait(1/2)
#         self.play(DrawBorderThenFill(blue_grid))
#         self.play(blue_grid.animate.to_edge(RIGHT))
#         self.wait()
#
#         self.play(blue_grid.animate.next_to(red_grid, RIGHT).set_color(RED))
#         self.wait()
#         self.play(blue_grid.animate.to_edge(RIGHT).set_color(BLUE))
#         self.play(red_grid.animate.next_to(blue_grid, LEFT).set_color(BLUE))
#         self.wait(2)
#         self.play(red_grid.animate.to_edge(LEFT).set_color(RED))
#         self.wait()
#         self.play(red_grid.animate.move_to(ORIGIN).set_color(WHITE), blue_grid.animate.set_opacity(0))
#
#         animations = []
#         for dot in red_grid:
#             animations.append(Transform(dot, white_dot))
#         self.play(*animations)
#
#         self.wait(5)
# Out:
# Manim Community v0.20.1
# <video src="media/jupyter/DotsCreation@2026-04-20@13-59-35.mp4" controls autoplay loop style="max-width: 75%;"  >
#       Your browser does not support the <code>video</code> element.
#     </video>
